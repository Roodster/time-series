# %%
path = 'datasets/airline-passengers.csv'

# %%
#**********************************************************************
#Slide-34: Fixing Non-constant Variance + Trend Removal
#**********************************************************************
from pandas import read_csv
from pandas import Series
import pandas as pd
from scipy.stats import boxcox
import matplotlib.pyplot as plt
series = read_csv(path, header=0, parse_dates=[0], index_col=0, squeeze=True)
series_boxcox, lam= boxcox(series)
series_boxcox=pd.DataFrame(series_boxcox)
series_boxcox_diff = series_boxcox.diff()
plt.plot(series)
plt.plot(series_boxcox_diff)
# Out:
# C:\Users\Interns\AppData\Local\Temp\ipykernel_10992\1727757728.py:9: FutureWarning: The squeeze argument has been deprecated and will be removed in a future version. Append .squeeze("columns") to the call to squeeze.
#
#
#   series = read_csv(path, header=0, parse_dates=[0], index_col=0, squeeze=True)
